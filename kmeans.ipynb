# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.cluster import KMeans

# %%
univ=pd.read_csv("Universities.csv")
univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# 13     PennState  1081     38      54       18     10185        80
# 14     Princeton  1375     91      14        8     30220        95
# 15        Purdue  1005     28      90       19      9066        69
# 16      Stanford  1360     90      20       12     36450        93
# 17      TexasA&M  1075     49      67       25      8704        67
# 18    UCBerkeley  1240     95      40       17     15140        78
# 19      UChicago  1290     75      50       13     38380        87
# 20     UMichigan  1180     65      68       16     15470        85
# 21         UPenn  1285     80      36       11     27553        90
# 22           UVA  1225     77      44       14     13349        92
# 23    UWisconsin  1085     40      69       15     11857        71
# 24          Yale  1375     95      19       11     43514        96

# %%
univ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
univ.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %% [markdown]
# #### Standardization of the data

# %%
univ1=univ.iloc[:,1:]
univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# 13     PennState  1081     38      54       18     10185        80
# 14     Princeton  1375     91      14        8     30220        95
# 15        Purdue  1005     28      90       19      9066        69
# 16      Stanford  1360     90      20       12     36450        93
# 17      TexasA&M  1075     49      67       25      8704        67
# 18    UCBerkeley  1240     95      40       17     15140        78
# 19      UChicago  1290     75      50       13     38380        87
# 20     UMichigan  1180     65      68       16     15470        85
# 21         UPenn  1285     80      36       11     27553        90
# 22           UVA  1225     77      44       14     13349        92
# 23    UWisconsin  1085     40      69       15     11857        71
# 24          Yale  1375     95      19       11     43514        96

# %%
cols=univ1.columns

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_univ_df=pd.DataFrame(scaler.fit_transform(univ1),columns=cols)
scaled_univ_df
# Out:
#          SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0   0.410284  0.657519 -0.889867  0.070260 -0.331413  0.820303
# 1   1.399259  1.235212 -0.734657 -1.686251  2.560381 -0.644524
# 2  -0.060657 -0.760454  1.024382 -0.933460 -0.167121 -1.658634
# 3   0.410284 -0.025208 -0.786394 -0.180670  0.291649  0.144229
# 4   0.127719  0.342414 -0.320766  0.070260 -0.390846  0.369587
# 5   0.692848  0.657519 -0.838130 -0.682530  0.337780  0.932982
# 6   0.457378  0.710037 -0.475975 -0.180670  0.296955  0.932982
# 7  -0.107751 -0.130243 -0.786394 -0.180670 -0.513817  0.594945
# 8   1.257977  0.762555 -1.303758 -0.431600  0.858743  1.158339
# 9   0.363190 -0.077726  0.248335 -1.435321  2.214818  0.031550
# 10  1.069601  0.920107 -0.475975 -0.682530  0.529383  0.482266
# 11 -0.060657  0.447449 -0.010347 -0.431600  0.046981  0.256908
# 12 -0.107751  0.237379  0.144862  0.070260 -0.867871  0.820303
# 13 -1.746625 -2.020875  0.765699  1.324911 -1.217184 -0.757202
# 14  1.022507  0.762555 -1.303758 -1.184390  0.200376  0.932982
# 15 -2.462455 -2.546050  2.628211  1.575841 -1.296358 -1.996671
# 16  0.881224  0.710037 -0.993340 -0.180670  0.641174  0.707624
# 17 -1.803138 -1.443182  1.438273  3.081422 -1.321971 -2.222029
# 18 -0.249033  0.972625  0.041389  1.073981 -0.866597 -0.982560
# 19  0.221907 -0.077726  0.558754  0.070260  0.777730  0.031550
# 20 -0.814162 -0.602901  1.490010  0.823051 -0.843248 -0.193808
# 21  0.174813  0.184862 -0.165557 -0.431600  0.011674  0.369587
# 22 -0.390316  0.027309  0.248335  0.321191 -0.993318  0.594945
# 23 -1.708950 -1.915840  1.541746  0.572121 -1.098883 -1.771313
# 24  1.022507  0.972625 -1.045076 -0.431600  1.140982  1.045661

# %%
univ[univ.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Univ, SAT, Top10, Accept, SFRatio, Expenses, GradRate]
# Index: []

# %%
plt.figure(figsize=(6,2))
plt.boxplot(univ["SAT"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27060488560>,
#   <matplotlib.lines.Line2D at 0x270604895e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x27060484f80>,
#   <matplotlib.lines.Line2D at 0x27060489bb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2705dd68c80>],
#  'medians': [<matplotlib.lines.Line2D at 0x27060489310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2706048a510>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
plt.boxplot(univ["Accept"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x270610a73b0>,
#   <matplotlib.lines.Line2D at 0x270610a76b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x270610a78f0>,
#   <matplotlib.lines.Line2D at 0x270610a7a70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x270610a4bf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x270610a7d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x270610a7f80>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
plt.boxplot(univ["SFRatio"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2706111e510>,
#   <matplotlib.lines.Line2D at 0x2706111e7b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2706111eab0>,
#   <matplotlib.lines.Line2D at 0x2706111ec60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2706111e240>],
#  'medians': [<matplotlib.lines.Line2D at 0x2706111ef00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2706111f200>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
plt.boxplot(univ["Expenses"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2706118db50>,
#   <matplotlib.lines.Line2D at 0x2706118dd90>],
#  'caps': [<matplotlib.lines.Line2D at 0x2706118e060>,
#   <matplotlib.lines.Line2D at 0x2706118e210>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2706118d880>],
#  'medians': [<matplotlib.lines.Line2D at 0x2706118e4e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2706118e750>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
plt.boxplot(univ["GradRate"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x270611e79b0>,
#   <matplotlib.lines.Line2D at 0x270611e7c20>],
#  'caps': [<matplotlib.lines.Line2D at 0x270611e7ec0>,
#   <matplotlib.lines.Line2D at 0x2706120c050>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2705e117ec0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2706120c2c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2706120c4d0>],
#  'means': []}
