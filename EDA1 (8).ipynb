# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("data_clean.csv")
print(data)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
#draw column that not needed.
data_cleaned=data.drop(['Unnamed: 0','Temp C'],axis=1)
data_cleaned
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
#convert the datatype of month column.
data_cleaned['Month']=pd.to_numeric(data['Month'],errors='coerce')
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data_cleaned.describe()
# Out:
#             Ozone     Solar.R        Wind       Month         Day    Year  \
# count  120.000000  151.000000  158.000000  157.000000  158.000000   158.0
# mean    41.583333  185.403974    9.957595    7.044586   16.006329  2010.0
# std     32.620709   88.723103    3.511261    1.433768    8.997166     0.0
# min      1.000000    7.000000    1.700000    5.000000    1.000000  2010.0
# 25%     18.000000  119.000000    7.400000    6.000000    8.000000  2010.0
# 50%     30.500000  197.000000    9.700000    7.000000   16.000000  2010.0
# 75%     61.500000  257.000000   11.875000    8.000000   24.000000  2010.0
# max    168.000000  334.000000   20.700000    9.000000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
#checking duplicate rows.
data_cleaned[data_cleaned.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data_cleaned[data_cleaned.duplicated(keep=False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
#rename the column
data_cleaned.rename({'Solar.R':'Solar'},axis=1 ,inplace=True)
data_cleaned
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 156   14.0  191.0  14.3    9.0   28  2010    75       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar    151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data_cleaned.isnull().sum() #display missing values count in each column.
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
cols=data_cleaned.columns
colours=['black','yellow']
sns.heatmap(data_cleaned[cols].isnull(),cmap=sns.color_palette(colours),cbar=True)
# Out:
# <Axes: >

# %%
#mean and median values
#(imputation of missing values)
median_ozone=data_cleaned["Ozone"].median()
mean_ozone=data_cleaned["Ozone"].mean()
print("mean_ozone: ",mean_ozone)
print("median_ozone: ",median_ozone)
# Out:
# mean_ozone:  41.583333333333336
# median_ozone:  30.5

# %%
data_cleaned['Ozone']=data_cleaned['Ozone'].fillna(median_ozone) 
data_cleaned.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
data_cleaned['Solar']=data_cleaned['Solar'].fillna(median_ozone) 
data_cleaned.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
print(data_cleaned["Weather"].value_counts())
mode_weather=data_cleaned["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     59
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data_cleaned["Weather"]=data_cleaned["Weather"].fillna(mode_weather)
data_cleaned.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
print(data_cleaned["Month"].value_counts())
mode_month=data_cleaned["Month"].mode()[0]
print(mode_month)
# Out:
# Month
# 9.0    34
# 5.0    31
# 7.0    31
# 8.0    31
# 6.0    30
# Name: count, dtype: int64
# 9.0

# %%
data_cleaned["Month"]=data_cleaned["Month"].fillna(mode_month)
data_cleaned.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
mode_weather=data_cleaned["Weather"].mode()
print(mode_weather)
# Out:
# 0    S
# Name: Weather, dtype: object

# %%
data_cleaned.tail()
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   30.5  145.0  13.2    9.0   27  2010    77       S
# 156   14.0  191.0  14.3    9.0   28  2010    75       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C

# %%
data_cleaned.reset_index(drop=True)
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     30.5   30.5  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   30.5  145.0  13.2    9.0   27  2010    77       S
# 156   14.0  191.0  14.3    9.0   28  2010    75       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
#detection of outliers
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})

# Plot the boxplot in the first (top) subplot
sns.boxplot(data=data_cleaned["Ozone"], ax=axes[0], color='skyblue', width=0.5, orient = 'h')
axes [0].set_title("Boxplot")
axes [0].set_xlabel("Ozone Levels")

# Plot the histogram with KDE curve in the second (bottom) subplot
sns.histplot(data_cleaned["Ozone"], kde=True, ax=axes[1], color='purple', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observations:
# 1)beyond 80 ozone levels we have Outliers
# 2)right-skewed histogram

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})

# Plot the boxplot in the first (top) subplot
sns.boxplot(data=data_cleaned["Solar"], ax=axes[0], color='skyblue', width=0.5, orient = 'h')
axes [0].set_title("Boxplot")
axes [0].set_xlabel("Solar Levels")

# Plot the histogram with KDE curve in the second (bottom) subplot
sns.histplot(data_cleaned["Solar"], kde=True, ax=axes[1], color='purple', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Solar Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observations:
# 1)there are no outliers.
# 2)left-skewed histogram.

# %%
# Create a figure for violin plot

sns.violinplot(data=data_cleaned["Ozone"], color='lightgreen')
plt.title("Violin Plot")

#Show the plot
plt.show()

# %%
# Create a figure for violin plot

sns.violinplot(data=data_cleaned["Solar"], color='lightblue')
plt.title("Violin Plot")

#Show the plot
plt.show()

# %%
plt.figure(figsize=(6,2))
plt.boxplot(data_cleaned["Ozone"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x237fbd11340>,
#   <matplotlib.lines.Line2D at 0x237fbd115e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x237fbd11880>,
#   <matplotlib.lines.Line2D at 0x237fbd11a30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x237fbd110a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x237fbd11d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x237fbd12000>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
plt.boxplot(data_cleaned["Solar"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x237fbd94620>,
#   <matplotlib.lines.Line2D at 0x237fbd94aa0>],
#  'caps': [<matplotlib.lines.Line2D at 0x237fbd94d70>,
#   <matplotlib.lines.Line2D at 0x237fbd94f50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x237fbd947a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x237fbd95220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x237fbd95520>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
boxplot_data=plt.boxplot(data_cleaned["Ozone"],vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %% [markdown]
# Method 2 for outlier detection

# %%
data_cleaned['Ozone'].describe()
# Out:
# count    158.000000
# mean      38.917722
# std       28.794730
# min        1.000000
# 25%       21.000000
# 50%       30.500000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu=data_cleaned["Ozone"].describe()[1]
sigma =data_cleaned["Ozone"].describe()[2]
for x in data_cleaned["Ozone"]:
    if((x<(mu - 3*sigma)) or (x > (mu+ 3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\user\AppData\Local\Temp\ipykernel_11532\3502073944.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu=data_cleaned["Ozone"].describe()[1]
# C:\Users\user\AppData\Local\Temp\ipykernel_11532\3502073944.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma =data_cleaned["Ozone"].describe()[2]

# %% [markdown]
# observation:
# Its observed that only two outliers are identified
# i the boxplot method more no. of outliers are identified
# this is because the assumption of normality is not satisfied in this column

# %%
import scipy.stats as stats

# Create Q-Q plot
plt.figure(figsize=(8, 6))
stats.probplot(data_cleaned["Ozone"], dist="norm", plot=plt)
plt.title("Q-Q Plot for Outlier Detection", fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %% [markdown]
# Observation from Q-Q plot
# The data doesnt follow normal distribution.
# The data shows a right skewed distribution.

# %%
import scipy.stats as stats

# Create Q-Q plot
plt.figure(figsize=(8, 6))
stats.probplot(data_cleaned["Solar"], dist="norm", plot=plt)
plt.title("Q-Q Plot for Outlier Detection", fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %%
sns.swarmplot(data=data_cleaned,x="Weather",y="Ozone",color="orange",palette="Set2",size=6)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11532\530296315.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data_cleaned,x="Weather",y="Ozone",color="orange",palette="Set2",size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.swarmplot(data=data_cleaned,x="Weather",y="Solar",color="orange",palette="Set2",size=6)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11532\2339978895.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data_cleaned,x="Weather",y="Solar",color="orange",palette="Set2",size=6)
# <Axes: xlabel='Weather', ylabel='Solar'>

# %%
sns.stripplot(data=data_cleaned,x="Weather",y="Ozone",color="orange",palette="Set1",size=6,jitter=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11532\749178314.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data_cleaned,x="Weather",y="Ozone",color="orange",palette="Set1",size=6,jitter=True)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.stripplot(data=data_cleaned,x="Weather",y="Solar",color="orange",palette="Set1",size=6,jitter=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11532\1032578622.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data_cleaned,x="Weather",y="Solar",color="orange",palette="Set1",size=6,jitter=True)
# <Axes: xlabel='Weather', ylabel='Solar'>

# %%
sns.kdeplot(data=data_cleaned["Ozone"],fill=True,color="blue")
sns.rugplot(data=data_cleaned["Ozone"],color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
sns.boxplot(data=data_cleaned,x="Weather",y="Ozone")
# Out:
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
plt.scatter(data_cleaned["Wind"],data_cleaned["Temp"])

# %%
data_cleaned["Wind"].corr(data_cleaned["Temp"]) #correlation coeff.
# Out:
# -0.441246717631239

# %% [markdown]
# Observation
# the correlation between wind and temp is observed to be negatively correlated with mild strength.

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    158 non-null    float64
#  1   Solar    158 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  158 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data_cleaned_numeric=data_cleaned.iloc[:,[0,1,2,6]]
data_cleaned_numeric
# Out:
#      Ozone  Solar  Wind  Temp
# 0     41.0  190.0   7.4    67
# 1     36.0  118.0   8.0    72
# 2     12.0  149.0  12.6    74
# 3     18.0  313.0  11.5    62
# 4     30.5   30.5  14.3    56
# ..     ...    ...   ...   ...
# 153   41.0  190.0   7.4    67
# 154   30.0  193.0   6.9    70
# 155   30.5  145.0  13.2    77
# 156   14.0  191.0  14.3    75
# 157   18.0  131.0   8.0    76
#
# [158 rows x 4 columns]

# %%
data_cleaned_numeric.corr()
# Out:
#           Ozone     Solar      Wind      Temp
# Ozone  1.000000  0.276848 -0.526616  0.596304
# Solar  0.276848  1.000000 -0.031312  0.282061
# Wind  -0.526616 -0.031312  1.000000 -0.441247
# Temp   0.596304  0.282061 -0.441247  1.000000

# %% [markdown]
# 1) MAx corr is identified between ozone and temp(0.597).
# 2) Next max corr is between ozone and wind(-0.5266).
# 3) Next max corr is between wind and temp(-0.44).
# 4) the least corr is between solar and wind(-0.055).

# %%
sns.pairplot(data_cleaned_numeric)

# %%
import pandas as pd
data2=pd.get_dummies(data_cleaned,columns=['Month','Weather'])
data2
# Out:
#      Ozone  Solar  Wind  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  \
# 0     41.0  190.0   7.4    1  2010    67       True      False      False
# 1     36.0  118.0   8.0    2  2010    72       True      False      False
# 2     12.0  149.0  12.6    3  2010    74       True      False      False
# 3     18.0  313.0  11.5    4  2010    62       True      False      False
# 4     30.5   30.5  14.3    5  2010    56       True      False      False
# ..     ...    ...   ...  ...   ...   ...        ...        ...        ...
# 153   41.0  190.0   7.4    1  2010    67       True      False      False
# 154   30.0  193.0   6.9   26  2010    70      False      False      False
# 155   30.5  145.0  13.2   27  2010    77      False      False      False
# 156   14.0  191.0  14.3   28  2010    75      False      False      False
# 157   18.0  131.0   8.0   29  2010    76      False      False      False
#
#      Month_8.0  Month_9.0  Weather_C  Weather_PS  Weather_S
# 0        False      False      False       False       True
# 1        False      False       True       False      False
# 2        False      False      False        True      False
# 3        False      False      False       False       True
# 4        False      False      False       False       True
# ..         ...        ...        ...         ...        ...
# 153      False      False       True       False      False
# 154      False       True      False        True      False
# 155      False       True      False       False       True
# 156      False       True      False       False       True
# 157      False       True       True       False      False
#
# [158 rows x 14 columns]

# %% [markdown]
# NORMALIZATION OF DATA

# %%
data_cleaned_numeric.values
# Out:
# array([[ 41. , 190. ,   7.4,  67. ],
#        [ 36. , 118. ,   8. ,  72. ],
#        [ 12. , 149. ,  12.6,  74. ],
#        [ 18. , 313. ,  11.5,  62. ],
#        [ 30.5,  30.5,  14.3,  56. ],
#        [ 28. ,  30.5,  14.9,  66. ],
#        [ 23. , 299. ,   8.6,  65. ],
#        [ 19. ,  99. ,  13.8,  59. ],
#        [  8. ,  19. ,  20.1,  61. ],
#        [ 30.5, 194. ,   8.6,  69. ],
#        [  7. ,  30.5,   6.9,  74. ],
#        [ 16. , 256. ,   9.7,  69. ],
#        [ 11. , 290. ,   9.2,  66. ],
#        [ 14. , 274. ,  10.9,  68. ],
#        [ 18. ,  65. ,  13.2,  58. ],
#        [ 14. , 334. ,  11.5,  64. ],
#        [ 34. , 307. ,  12. ,  66. ],
#        [  6. ,  78. ,  18.4,  57. ],
#        [ 30. , 322. ,  11.5,  68. ],
#        [ 11. ,  44. ,   9.7,  62. ],
#        [  1. ,   8. ,   9.7,  59. ],
#        [ 11. , 320. ,  16.6,  73. ],
#        [  4. ,  25. ,   9.7,  61. ],
#        [ 32. ,  92. ,  12. ,  61. ],
#        [ 30.5,  66. ,  16.6,  57. ],
#        [ 30.5, 266. ,  14.9,  58. ],
#        [ 30.5,  30.5,   8. ,  57. ],
#        [ 23. ,  13. ,  12. ,  67. ],
#        [ 45. , 252. ,  14.9,  81. ],
#        [115. , 223. ,   5.7,  79. ],
#        [ 37. , 279. ,   7.4,  76. ],
#        [ 30.5, 286. ,   8.6,  78. ],
#        [ 30.5, 287. ,   9.7,  74. ],
#        [ 30.5, 242. ,  16.1,  67. ],
#        [ 30.5, 186. ,   9.2,  84. ],
#        [ 30.5, 220. ,   8.6,  85. ],
#        [ 30.5, 264. ,  14.3,  79. ],
#        [ 29. , 127. ,   9.7,  82. ],
#        [ 30.5, 273. ,   6.9,  87. ],
#        [ 71. , 291. ,  13.8,  90. ],
#        [ 39. , 323. ,  11.5,  87. ],
#        [ 30.5, 259. ,  10.9,  93. ],
#        [ 30.5, 250. ,   9.2,  92. ],
#        [ 23. , 148. ,   8. ,  82. ],
#        [ 30.5, 332. ,  13.8,  80. ],
#        [ 30.5, 322. ,  11.5,  79. ],
#        [ 21. , 191. ,  14.9,  77. ],
#        [ 37. , 284. ,  20.7,  72. ],
#        [ 20. ,  37. ,   9.2,  65. ],
#        [ 12. , 120. ,  11.5,  73. ],
#        [ 13. , 137. ,  10.3,  76. ],
#        [ 30.5, 150. ,   6.3,  77. ],
#        [ 30.5,  59. ,   1.7,  76. ],
#        [ 30.5,  91. ,   4.6,  76. ],
#        [ 30.5, 250. ,   6.3,  76. ],
#        [ 30.5, 135. ,   8. ,  75. ],
#        [ 30.5, 127. ,   8. ,  78. ],
#        [ 30.5,  47. ,  10.3,  73. ],
#        [ 30.5,  98. ,  11.5,  80. ],
#        [ 30.5,  31. ,  14.9,  77. ],
#        [ 30.5, 138. ,   8. ,  83. ],
#        [135. , 269. ,   4.1,  84. ],
#        [ 49. , 248. ,   9.2,  85. ],
#        [ 32. , 236. ,   9.2,  81. ],
#        [ 30.5, 101. ,  10.9,  84. ],
#        [ 64. , 175. ,   4.6,  83. ],
#        [ 40. , 314. ,  10.9,  83. ],
#        [ 77. , 276. ,   5.1,  88. ],
#        [ 97. , 267. ,   6.3,  92. ],
#        [ 97. , 272. ,   5.7,  92. ],
#        [ 85. , 175. ,   7.4,  89. ],
#        [ 30.5, 139. ,   8.6,  82. ],
#        [ 10. , 264. ,  14.3,  73. ],
#        [ 27. , 175. ,  14.9,  81. ],
#        [ 30.5, 291. ,  14.9,  91. ],
#        [  7. ,  48. ,  14.3,  80. ],
#        [ 48. , 260. ,   6.9,  81. ],
#        [ 35. , 274. ,  10.3,  82. ],
#        [ 61. , 285. ,   6.3,  84. ],
#        [ 79. , 187. ,   5.1,  87. ],
#        [ 63. , 220. ,  11.5,  85. ],
#        [ 16. ,   7. ,   6.9,  74. ],
#        [ 30.5, 258. ,   9.7,  81. ],
#        [ 30.5, 295. ,  11.5,  82. ],
#        [ 80. , 294. ,   8.6,  86. ],
#        [108. , 223. ,   8. ,  85. ],
#        [ 20. ,  81. ,   8.6,  82. ],
#        [ 52. ,  82. ,  12. ,  86. ],
#        [ 82. , 213. ,   7.4,  88. ],
#        [ 50. , 275. ,   7.4,  86. ],
#        [ 64. , 253. ,   7.4,  83. ],
#        [ 59. , 254. ,   9.2,  81. ],
#        [ 39. ,  83. ,   6.9,  81. ],
#        [  9. ,  24. ,  13.8,  81. ],
#        [ 16. ,  77. ,   7.4,  82. ],
#        [ 78. ,  30.5,   6.9,  86. ],
#        [ 35. ,  30.5,   7.4,  85. ],
#        [ 66. ,  30.5,   4.6,  87. ],
#        [122. , 255. ,   4. ,  89. ],
#        [ 89. , 229. ,  10.3,  90. ],
#        [110. , 207. ,   8. ,  90. ],
#        [ 30.5, 222. ,   8.6,  92. ],
#        [ 30.5, 137. ,  11.5,  86. ],
#        [ 44. , 192. ,  11.5,  86. ],
#        [ 28. , 273. ,  11.5,  82. ],
#        [ 65. , 157. ,   9.7,  80. ],
#        [ 30.5,  64. ,  11.5,  79. ],
#        [ 22. ,  71. ,  10.3,  77. ],
#        [ 59. ,  51. ,   6.3,  79. ],
#        [ 23. , 115. ,   7.4,  76. ],
#        [ 31. , 244. ,  10.9,  78. ],
#        [ 44. , 190. ,  10.3,  78. ],
#        [ 21. , 259. ,  15.5,  77. ],
#        [  9. ,  36. ,  14.3,  72. ],
#        [ 30.5, 255. ,  12.6,  75. ],
#        [ 45. , 212. ,   9.7,  79. ],
#        [168. , 238. ,   3.4,  81. ],
#        [ 73. , 215. ,   8. ,  86. ],
#        [ 30.5, 153. ,   5.7,  88. ],
#        [ 76. , 203. ,   9.7,  97. ],
#        [118. , 225. ,   2.3,  94. ],
#        [ 84. , 237. ,   6.3,  96. ],
#        [ 85. , 188. ,   6.3,  94. ],
#        [ 96. , 167. ,   6.9,  91. ],
#        [ 78. , 197. ,   5.1,  92. ],
#        [ 73. , 183. ,   2.8,  93. ],
#        [ 91. , 189. ,   4.6,  93. ],
#        [ 47. ,  95. ,   7.4,  87. ],
#        [ 32. ,  92. ,  15.5,  84. ],
#        [ 20. , 252. ,  10.9,  80. ],
#        [ 23. , 220. ,  10.3,  78. ],
#        [ 21. , 230. ,  10.9,  75. ],
#        [ 24. , 259. ,   9.7,  73. ],
#        [ 44. , 236. ,  14.9,  81. ],
#        [ 21. , 259. ,  15.5,  76. ],
#        [ 28. , 238. ,   6.3,  77. ],
#        [  9. ,  24. ,  10.9,  71. ],
#        [ 13. , 112. ,  11.5,  71. ],
#        [ 46. , 237. ,   6.9,  78. ],
#        [ 18. , 224. ,  13.8,  67. ],
#        [ 13. ,  27. ,  10.3,  76. ],
#        [ 24. , 238. ,  10.3,  68. ],
#        [ 16. , 201. ,   8. ,  82. ],
#        [ 13. , 238. ,  12.6,  64. ],
#        [ 23. ,  14. ,   9.2,  71. ],
#        [ 36. , 139. ,  10.3,  81. ],
#        [  7. ,  49. ,  10.3,  69. ],
#        [ 14. ,  20. ,  16.6,  63. ],
#        [ 30. , 193. ,   6.9,  70. ],
#        [ 30.5, 145. ,  13.2,  77. ],
#        [ 14. , 191. ,  14.3,  75. ],
#        [ 18. , 131. ,   8. ,  76. ],
#        [ 20. , 223. ,  11.5,  68. ],
#        [ 41. , 190. ,   7.4,  67. ],
#        [ 30. , 193. ,   6.9,  70. ],
#        [ 30.5, 145. ,  13.2,  77. ],
#        [ 14. , 191. ,  14.3,  75. ],
#        [ 18. , 131. ,   8. ,  76. ]])

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

array=data_cleaned_numeric.values
scaler=MinMaxScaler(feature_range=(0,1))
rescaledX=scaler.fit_transform(array)

set_printoptions(precision=2)
print(rescaledX[0:10,:])
# Out:
# [[0.24 0.56 0.3  0.27]
#  [0.21 0.34 0.33 0.39]
#  [0.07 0.43 0.57 0.44]
#  [0.1  0.94 0.52 0.15]
#  [0.18 0.07 0.66 0.  ]
#  [0.16 0.07 0.69 0.24]
#  [0.13 0.89 0.36 0.22]
#  [0.11 0.28 0.64 0.07]
#  [0.04 0.04 0.97 0.12]
#  [0.18 0.57 0.36 0.32]]

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler
array=data_cleaned_numeric.values
scaler =MinMaxScaler(feature_range=(0,1))
resclaedX=scaler.fit_transform(array)
set_printoptions(precision=2)
print(rescaledX[0:10,:])
# Out:
# [[0.24 0.56 0.3  0.27]
#  [0.21 0.34 0.33 0.39]
#  [0.07 0.43 0.57 0.44]
#  [0.1  0.94 0.52 0.15]
#  [0.18 0.07 0.66 0.  ]
#  [0.16 0.07 0.69 0.24]
#  [0.13 0.89 0.36 0.22]
#  [0.11 0.28 0.64 0.07]
#  [0.04 0.04 0.97 0.12]
#  [0.18 0.57 0.36 0.32]]

# %%
## from sklearn.preprocessing import StandardScaler

array=data_cleaned_numeric.values
scaler=StandardScaler()
rescaledX=scaler.fit_transform(array)


set_printoptions(precision=3)
print(rescaledX[0:10,:])
# Out:
# [[ 0.073  0.124 -0.731 -1.148]
#  [-0.102 -0.657 -0.559 -0.613]
#  [-0.938 -0.321  0.755 -0.399]
#  [-0.729  1.459  0.441 -1.682]
#  [-0.293 -1.607  1.241 -2.324]
#  [-0.38  -1.607  1.412 -1.255]
#  [-0.555  1.307 -0.388 -1.362]
#  [-0.694 -0.863  1.098 -2.003]
#  [-1.077 -1.732  2.898 -1.789]
#  [-0.293  0.168 -0.388 -0.934]]
