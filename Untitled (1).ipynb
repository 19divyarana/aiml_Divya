# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %%
toyoto=pd.read_csv("Toyoto_Corrola.csv")
toyoto
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3     ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 0            23  46986   90      3          4      5    1165
# ...

# %%
toyoto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         1436 non-null   int64
#  1   Model      1436 non-null   object
#  2   Price      1436 non-null   int64
#  3   Age_08_04  1436 non-null   int64
#  4   KM         1436 non-null   int64
#  5   HP         1436 non-null   int64
#  6   Doors      1436 non-null   int64
#  7   Cylinders  1436 non-null   int64
#  8   Gears      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 112.3+ KB

# %%
toyoto.isnull().sum()
# Out:
# Id           0
# Model        0
# Price        0
# Age_08_04    0
# KM           0
# HP           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
toyoto1=toyoto.drop(columns=["Model","Id"])
toyoto1
# Out:
#       Price  Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 0     13500         23  46986   90      3          4      5    1165
# 1     13750         23  72937   90      3          4      5    1165
# 2     13950         24  41711   90      3          4      5    1165
# 3     14950         26  48000   90      3          4      5    1165
# 4     13750         30  38500   90      3          4      5    1170
# ...     ...        ...    ...  ...    ...        ...    ...     ...
# 1431   7500         69  20544   86      3          4      5    1025
# 1432  10845         72  19000   86      3          4      5    1015
# 1433   8500         71  17016   86      3          4      5    1015
# 1434   7250         70  16916   86      3          4      5    1015
# 1435   6950         76      1  110      5          4      5    1114
#
# [1436 rows x 8 columns]

# %%
toyoto1.rename(columns={'Age_08_04':'Age'},inplace=True)
toyoto1
# Out:
#       Price  Age     KM   HP  Doors  Cylinders  Gears  Weight
# 0     13500   23  46986   90      3          4      5    1165
# 1     13750   23  72937   90      3          4      5    1165
# 2     13950   24  41711   90      3          4      5    1165
# 3     14950   26  48000   90      3          4      5    1165
# 4     13750   30  38500   90      3          4      5    1170
# ...     ...  ...    ...  ...    ...        ...    ...     ...
# 1431   7500   69  20544   86      3          4      5    1025
# 1432  10845   72  19000   86      3          4      5    1015
# 1433   8500   71  17016   86      3          4      5    1015
# 1434   7250   70  16916   86      3          4      5    1015
# 1435   6950   76      1  110      5          4      5    1114
#
# [1436 rows x 8 columns]

# %%
toyoto1.isna().sum()
# Out:
# Price        0
# Age          0
# KM           0
# HP           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
toyoto1[toyoto1.duplicated(keep=False)]
# Out:
#      Price  Age     KM   HP  Doors  Cylinders  Gears  Weight
# 112  24950    8  13253  116      5          4      5    1320
# 113  24950    8  13253  116      5          4      5    1320

# %% [markdown]
# #### Observation
# - there are no nll values.
# - there are duplicated row i.e; 113,112.
# - thecontinous variable colmns: Price,Age, HP,KM,Weight
# - the categorical columns are cylinders,doors,gears.
# - the price column is the predicted variable.

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# Creating a boxplot
sns.boxplot(data=toyoto, x='Price', ax=ax_box, orient='h' )
ax_box.set(xlabel='') # Remove x Label for the boxplot

# Creating a histogram in the same x-axis
sns.histplot(data=toyoto, x='Price', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

#Adjust Layout
plt.tight_layout()
plt.show()

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# Creating a boxplot
sns.boxplot(data=toyoto, x='KM', ax=ax_box, orient='h' )
ax_box.set(xlabel='') # Remove x Label for the boxplot

# Creating a histogram in the same x-axis
sns.histplot(data=toyoto, x='KM', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

#Adjust Layout
plt.tight_layout()
plt.show()

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# Creating a boxplot
sns.boxplot(data=toyoto, x='HP', ax=ax_box, orient='h' )
ax_box.set(xlabel='') # Remove x Label for the boxplot

# Creating a histogram in the same x-axis
sns.histplot(data=toyoto, x='HP', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

#Adjust Layout
plt.tight_layout()
plt.show()

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# Creating a boxplot
sns.boxplot(data=toyoto1, x='Age', ax=ax_box, orient='h' )
ax_box.set(xlabel='') # Remove x Label for the boxplot

# Creating a histogram in the same x-axis
sns.histplot(data=toyoto1, x='Age', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

#Adjust Layout
plt.tight_layout()
plt.show()

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# Creating a boxplot
sns.boxplot(data=toyoto, x='Weight', ax=ax_box, orient='h' )
ax_box.set(xlabel='') # Remove x Label for the boxplot

# Creating a histogram in the same x-axis
sns.histplot(data=toyoto, x='Weight', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

#Adjust Layout
plt.tight_layout()
plt.show()

# %%
toyoto1.drop_duplicates(keep='first',inplace=True)
toyoto1.reset_index(drop=True)
toyoto1
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3     ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1430  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1431  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1432  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1433  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1434  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 0            23  46986   90      3          4      5    1165
# ...

# %%
counts=toyoto1["Gears"].value_counts().reset_index()
print(counts)
